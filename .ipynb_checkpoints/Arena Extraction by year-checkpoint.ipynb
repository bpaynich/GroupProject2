# %%
import pandas as pd

# %%
arena = pd.read_table('./Resources/arena.txt')

# %%
arena_df = pd.DataFrame(arena)

# %%
arena_df = arena_df.rename(columns={arena_df.columns[0]: "Data" })
arena_df = arena_df[arena_df['Data'].str.contains('-')]
arena_df = arena_df[~arena_df['Data'].str.contains('Location|Phone|Website|Email|Founded|Arena:')]
#arena_df  = pd.DataFrame(arena_df['Data'].str.split().values.tolist())
#arena_df = arena_df.replace('\D+-\D+', '\D+-\D+\:', regex=True)
arena_df = arena_df.replace('- ', '-NOW', regex=True)
arena_df = arena_df.replace('  ', ':', regex=True)
arena_df = arena_df.replace('::', ':', regex=True)
arena_df = arena_df.replace('::', ':', regex=True)
arena_df = arena_df.replace('::', ':', regex=True)

arena_df = pd.DataFrame(arena_df['Data'].str.split(':').values.tolist())
#header_df  = header_df.rename(columns={header_df.columns[0]: "Status",
#                                     header_df.columns[1]: "Flow",
#                                     header_df.columns[2]: "Error",
#                                     header_df.columns[3]: "Warning"})
arena_df
# Out:
#                                        0                        1  \
# 0            1949-51 Wheaton Field House               Moline, IL
# 1                1951-55 Milwaukee Arena            Milwaukee, WI
# 2                1955-68 Kiel Auditorium            St. Louis, MO
# 3    1968-72 Alexander Memorial Coliseum              Atlanta, GA
# 4                  1972-97 Omni Coliseum              Atlanta, GA
# 5                   1997-99 Georgia Dome              Atlanta, GA
# 6                               1999-NOW            Philips Arena
# 7                  1946-95 Boston Garden               Boston, MA
# 8                   1995-05 Fleet Center               Boston, MA
# 9                               2005-NOW                TD Garden
# 10                              2004-NOW  Time Warner Cable Arena
# 11          1966-67 Chicago Amphitheater              Chicago, IL
# 12               1967-94 Chicago Stadium              Chicago, IL
# 13                              1994-NOW            United Center
# 14               1970-74 Cleveland Arena            Cleveland, OH
# 15                  1974-94 The Coliseum            Richfield, OH
# 16                    1994-05 Gund Arena
# 17                              2005-NOW      Quicken Loans Arean
# 18                 1980-01 Reunion Arena               Dallas, TX
# 19                                01-NOW  American Airlines Arena
# 20              1967-75 Auditorium Arena               Denver, CO
# 21        1975-99 McNichols Sports Arena               Denver, CO
# 22                              1999-NOW             Pepsi Center
# 23    1948-52 North Side High School Gym           Fort Wayne, IN
# 24             1952-57 Memorial Coliseum           Fort Wayne, IN
# 25               1957-61 Olympia Stadium              Detroit, MI
# 26                    1961-78 Cobo Arena
# 27                    1978-88 Silverdome
# 28                              1988-NOW   Palace of Auburn Hills
# 29            1946-52 Philadelphia Arena         Philadelphia, PA
# ..                                   ...                      ...
# 105                             2013-NOW        Sleep Train Arena
# 106           San Antonio, TX 78203-1031                     None
# 107          1967-70 Memorial Auditorium               Dallas, TX
# 108              1970-71 Moody Coliseum,               Dallas, TX
# 109               1971-73 Moody Coliseum               Dallas, TX
# 110              1973-93 HemisFair Arena    San Antonio,TX 16,057
# 111                    1993-02 Alamodome
# 112                   2002-10 SBC Center
# 113                             2010-NOW              AT&T Center
